# %% [markdown]
# # Exercise 1

# %% [markdown]
# # Week 0: Python Fundamentals - Exercises
#
# ## Instructions
#
# Complete the exercises below to practice what you've learned. Each exercise has:
# - A description of the task
# - Starter code
# - Expected output to verify your solution
#
# **Tip:** Try to solve each exercise without looking at the solutions first!
#
# ---

# %%
amount = 1000
interest_rate = 0.1

final_amount = 0

# %% [markdown]
# Use the base amount and interest rate to calculate the final amount after compound interest over 5 years.

# %% [markdown]
# **Expected Output:**
# ```
# The final amount is  1610.51
# ```
#
# **Hint:** Use a for loop to calculate compound interest: amount = amount * (1 + interest_rate) for each year

# %%
# Do your calculations here
# ...

# %%
print('The final amount is ', final_amount)

# %% [markdown]
# # Exercise 2

# %% [markdown]
# Calculate how many years you need to obtain a certain amount (e.g. 2000) by starting with an initial amount (e.g. 1000) for a given interest rate (e.g. 2%)

# %% [markdown]
# **Expected Output:**
# ```
# The number of years needed is  35
# ```
#
# **Hint:** Use a while loop that continues until the amount reaches the target

# %%
amount = 1000
target = 2000
interest_rate = 0.02

number_of_years = 0

# %%
# Do your calculations here
# ...

# %%
print('The number of years needed is ', number_of_years)

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Remove the duplicates from this list:

# %% [markdown]
# **Expected Output:**
# ```
# ['Johannes', 'Jamal', 'Galina']
# ```
#
# **Hint:** Convert the list to a set (which removes duplicates), then back to a list

# %%
name_list = ["Johannes", "Jamal", "Jamal", "Johannes", "Galina"]

# %%
# Enter your code here
# ...

# %% [markdown]
# Check the output:

# %%
print(name_list)

# %% [markdown]
# # Exercise 4

# %% [markdown]
# Make a list of all the 4th and 6th letters of a word:

# %% [markdown]
# **Expected Output:**
# ```
# ['an', 'an', 'an', 'an', 'in']
# ```
#
# **Hint:** Use a for loop and string indexing. Remember Python starts counting at 0!

# %%
words = ["Johannes", "Jamal", "Jamal", "Johannes", "Galina"]
new_list = []

# %%
# Enter your code here
# ...

# %%
print(new_list)

# %% [markdown]
# # Exercise 5

# %% [markdown]
# Create a list of temperatures in Fahrenheit from another list measured in Celsius using comprehensions:

# %% [markdown]
# **Expected Output:**
# ```
# [59.0, 64.4, 89.6, 66.2]
# ```
#
# **Hint:** Formula is F = C × 9/5 + 32. Use list comprehension: `[expression for item in list]`

# %%
celsius = [15, 18, 32, 19]

# Fill in the right comprehension
fahrenheit = []

# %% [markdown]
# Check the output:

# %%
print(fahrenheit)

# %% [markdown]
# # Exercise 6

# %% [markdown]
# Calculate how many years you need to obtain a certain amount by starting with an initial amount for a given interest rate

# %%
amounts = [1000,1200,1300]
target = 2000
interest_rates = [0.02,0.05,0.1]

# %% [markdown]
# You can use your previous code from exercise 2 and reuse it in a function:

# %% [markdown]
# **Expected Output:**
# ```
# Starting with £1000 at 2.0% interest, you need 35 years to reach £2000
# Starting with £1000 at 5.0% interest, you need 15 years to reach £2000
# Starting with £1000 at 10.0% interest, you need 8 years to reach £2000
# Starting with £1200 at 2.0% interest, you need 29 years to reach £2000
# Starting with £1200 at 5.0% interest, you need 11 years to reach £2000
# Starting with £1200 at 10.0% interest, you need 6 years to reach £2000
# Starting with £1300 at 2.0% interest, you need 25 years to reach £2000
# Starting with £1300 at 5.0% interest, you need 10 years to reach £2000
# Starting with £1300 at 10.0% interest, you need 5 years to reach £2000
# ```
#
# **Hint:** Define a function that takes amount, target, and interest_rate as parameters and returns the number of years

# %%
# Define function
# ...

# %%
# Loop over amounts and interest rates and call function
# Print an informative line of code
# ...

# %% [markdown]
# # Exercise 7

# %% [markdown]
# Calculate the number of ECTS taught by every member in the dictionary

# %% [markdown]
# **Expected Output:**
# ```
# Johannes teaches 15 ECTS
# Jamal teaches 15 ECTS
# Maurizio teaches 15 ECTS
# ```
#
# **Hint:** Loop through the courses dictionary and look up each course in the ects dictionary

# %%
courses = {"Johannes" : "Web Analytics", "Jamal" : "DEA", "Maurizio" : "Simulation"}
ects = {"Web Analytics": 15, "DEA": 15, "Simulation":15}

# %%
# Enter your code here
# ...

# %% [markdown]
# # Exercise 8

# %% [markdown]
# Find the most common letter at the third place in a word:

# %% [markdown]
# **Expected Output:**
# ```
# The most common letter at position 3 is: m (appears 2 times)
# ```
#
# **Hint:** Extract the 3rd letter from each word (index 2), count occurrences using a dictionary or Counter, then find the maximum

# %%
words = ["Johannes", "Jamal", "Jamal", "Adme", "Galina"]

# %%
# Enter your code here
# ...

# %% [markdown]
# # Exercise 9

# %% [markdown]
# **ADVANCED CHALLENGE:** In this exercise we are going to build a decision tree classifier using scikit-learn and pandas. This combines everything you've learned!
#
# Don't worry if this feels challenging - you can use scikit-learn's built-in functions for most tasks. The goal is to understand the workflow, not memorize the code.

# %%
import pandas as pd
import numpy as np

# Read csv with pandas, index indicates whether the first column is an index
data = pd.read_csv("data/attrition.csv", index_col=0)

print(data.head())

# %% [markdown]
# Attrition is our label, so we can split our data into X and y:

# %%
y = data['Attrition']
X = data.drop('Attrition', axis=1)

# %% [markdown]
# Write the pre-processing functions:

# %%
# Create training and test set with function
# Use sklearn.model_selection.train_test_split
# def splitDataset(X, y, ratio):
#     from sklearn.model_selection import train_test_split
#     # train_test_split returns: train_X, test_X, train_y, test_y
#     # The test_size parameter should be 1 - ratio (e.g., 0.3 for 70/30 split)
#     return train_test_split(X, y, test_size=1-ratio, random_state=42)
# ...

# %%
# Convert all attributes in data dataframe
# Use sklearn.preprocessing.LabelEncoder to convert text to numbers
# def convertAttribute(column):
#     from sklearn.preprocessing import LabelEncoder
#     le = LabelEncoder()
#     return le.fit_transform(column)
# ...

# %% [markdown]
# The pre-processsing:

# %%
# # convert all attributes at once      
# for column in X.columns:
#     X[column] = convertAttribute(X[column])

# y = convertAttribute(y)

# # Use our new function to split according to a certain ratio
# train_X, test_X, train_y, test_y = splitDataset(X, y, 0.7)

# %% [markdown]
# Build decision tree and calculate accuracy:

# %%
# # Build decision tree
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
# 
# tree = DecisionTreeClassifier(max_depth=5, random_state=42)
# tree.fit(train_X, train_y)
# 
# # Use tree for prediction
# y_pred = tree.predict(test_X)
# 
# # Calculate accuracy
# accuracy = accuracy_score(test_y, y_pred)
# print(f"Model accuracy: {accuracy:.2%}")

# Expected accuracy: around 75-85% (may vary due to random splitting)
